# %%
import numpy as np
import random
import json
import time
import json
import base64
import jwt
import pyshark
from jwcrypto import jwk
import jwt
import warnings
warnings.filterwarnings("ignore")
import gym_maze
import requests
import numpy as np
from PIL import Image
from gym_maze.envs.maze_manager import MazeManager
rids_solved = []
paths =[]
rid_time = {}
G_moves = {}
prev_acc = []
import easyocr
reader = easyocr.Reader(['en'])
    

rev_actions = {"N":"S","S":"N","E":"W","W":"E"}


def decode_jwt(token1):
    decoded = jwt.decode(token1, options={"verify_signature": False, "verify_aud": False, "audience": "my_audience"})
    iss1 = decoded.get("iss", "")
    aud1 = decoded.get("aud", "")
    id1 = decoded.get("id", "")
    scope1 = decoded.get("scope", "")
    name1 = decoded.get("name", "")
    email1 = decoded.get("email", "")
    rand1 = decoded.get("rand", "")
    return iss1, aud1, id1, scope1, name1, email1, rand1


def split_binary(binary_num, chunk_size):
    # Make sure the binary number is a string
    binary_str = str(binary_num)
    # Split the binary string into chunks of the given size
    binary_chunks = [binary_str[i:i + chunk_size] for i in range(0, len(binary_str), chunk_size)]

    return binary_chunks


def cipher_solver(encoded_string):
    
    padding = len(encoded_string) % 4
    if padding > 0:
        encoded_string += '=' * (4 - padding)

    decoded_bytes = base64.b64decode(encoded_string)
    decoded_string = decoded_bytes.decode('utf-8')

    binary_str = ''
    number_str = ''
    for char in decoded_string:
        if char.isdigit():
            number_str += char
        elif char == ',':
            binary_str += number_str
            number_str = ''

    tuple_str = '(' + binary_str + ',' + number_str + ')'

    split_tuple = tuple_str[1:-1].split(',')

    # Extract the binary string and integer value
    binary_str = split_tuple[0]
    integer_val = int(split_tuple[1])
    decimal_val = int(str(integer_val), 2)
    length = len(binary_str)
    parts=7


    binary_num = binary_str   # first input after base64 decode
    chunk_size = parts
    binary_chunks = split_binary(binary_num, chunk_size)
    output_string = ' '.join(binary_chunks)


    # Split binary string into chunks of 7 bits each
    binary_chunks = [binary_num[i:i+parts] for i in range(0, len(binary_num), parts)]

    # Convert binary chunks to decimal numbers
    decimal_nums = []
    for chunk in binary_chunks:
        decimal_nums.append(int(chunk, 2))

    new_list = []

    for item in decimal_nums:
        if item >= 65 and item <= 90:
            item -= decimal_val
            if item >= 65 and item <= 90:
                new_list.append(item)
            else:
                item += 26
                new_list.append(item)
        elif item >= 97 and item <= 122:
            item -= decimal_val
            if item >= 97 and item <= 122:
                new_list.append(item)
            else:
                item += 26
                new_list.append(item)

    ascii_list = new_list
    char_list = []

    for ascii_num in ascii_list:
        char_list.append(chr(ascii_num))
    final=''.join(char_list)
    return final


def captcha_solver(mylist):
    my_array = np.array(mylist)
    captcha_image = Image.fromarray(my_array.astype('uint8'))
    captcha_image = np.array(captcha_image)
    captcha_image = captcha_image[ :, ::].copy() 
    # Convert the numpy array to a Pillow image
    
    # Use pytesseract to convert the image to plain text
    result = reader.readtext(captcha_image)

    # Print the plain text
    return  result[0][-2]


def pcap_solver(stri):
    pass
    # stri = stri+"=="
    # decoded_data = base64.b64decode(stri)
    # with open('./output.bin', 'wb') as f:
    #     f.write(decoded_data)

    # capture = pyshark.FileCapture('./output.bin')

    # packet_str = ""  # Initialize an empty string to store the packets

    # for packet in capture:
    #     # Append the packet summary to the packet string
    #     packet_str += str(packet) + "\n"

    # capture.close()

    # pattern = "google.com:"

    # found_lines = set()
    # list=[]
    # newlist=[None]*4


    # for line in packet_str.splitlines():
    #     if pattern in line and line not in found_lines:
    #         found_lines.add(line)
    #         domain = line.split()[0]  # extract the first word (domain name)
    #         subdomain = domain.split('.')[1]  # extract the second-to-last part of the domain name
    #         list.append(subdomain)

    # newlist[0]=list[3]
    # newlist[1]=list[2]
    # newlist[2]=list[0]
    # newlist[3]=list[1]

    # decoded_list = []

    # for encoded_str in newlist:
    #     decoded_bytes = base64.b64decode(encoded_str)
    #     decoded_str = decoded_bytes.decode('utf-8')
    #     decoded_list.append(decoded_str)



    # final_string = ''.join(decoded_list)
    # return final_string

def server_solver(token1):
    
    with open("keypair.pem", "rb") as pemfile:
        key = jwk.JWK.from_pem(pemfile.read())
        public_key = key.export(private_key=False)

    jwks = {
        "e": key['e'],
        "kid": key.key_id,
        "kty": "RSA",
        "n": key['n']
    }

    header = {
        "kid": key.key_id,
        "typ": "JWT",
        "alg": "RS256",
        "jwk": jwks
    }

    fields = decode_jwt(token1)

    iss1, aud1, id1, scope1, name1, email1, rand1 = fields

    claims = {
        "iss": iss1,
        "aud": aud1,
        "id": id1,
        "scope": scope1,
        "name": name1,
        "email": email1,
        "admin": "true",
        "rand": rand1
    }
    key_pem = key.export_to_pem(private_key=True, password=None)
    signed_token = jwt.encode(payload=claims, key=key_pem, algorithm='RS256', headers=header)
    
    return signed_token.decode('utf-8')


# Loop through all possible points
for i in range(10):
    for j in range(10):
        # Create a tuple of the current point
        point = f"[{str(i)} {str(j)}]"
        # Set the value of the dictionary to ["N","S","E","W"]
        G_moves[str(point)] = ["N","S","E","W"]
        if j ==9:
            G_moves[str(point)].remove("S")
        if i ==9:
            G_moves[str(point)].remove("E")
        if j ==0:
            G_moves[str(point)].remove("N")
        if i ==0:
            G_moves[str(point)].remove("W")


def elemenate(action):
    c_point = paths[-1]
    if(action =='N'):
        rev = 'S'
        next_point =  c_point[:3]+ str(int(c_point[3])-1)+c_point[4:]
    elif(action =='S'):
        rev = 'N'
        next_point =  c_point[:3]+ str(int(c_point[3])+1)+c_point[4:]
    elif(action =='W'):
        rev = 'E'
        next_point =  c_point[:1]+ str(int(c_point[1])-1)+c_point[2:]
    elif(action =='E'):
        rev = 'W'
        next_point =  c_point[:1]+ str(int(c_point[1])+1)+c_point[2:]
    G_moves[next_point].remove(rev)


def save_action(action):
    prev_acc.append(action)


def cheak_point():
    if paths[-1] == paths[-2]:
        
        G_moves[paths[-1]].remove(prev_acc[-1])
        i = int(paths[-1][1])
        j = int(paths[-1][3])
        if(prev_acc[-1] =='N'):
            j-=1
            G_moves[f"[{i} {j}]"].remove("S")

        elif(prev_acc[-1] =='S'):
            j+=1
            G_moves[f"[{i} {j}]"].remove("N")
            
        elif(prev_acc[-1] =='W'):
            i-=1
            G_moves[f"[{i} {j}]"].remove("E")
            
        elif(prev_acc[-1] =='E'):
            i+=1
            G_moves[f"[{i} {j}]"].remove("W")
### the api calls must be modified by you according to the server IP communicated with you
#### students track --> 16.170.85.45
#### working professionals track --> 13.49.133.141
server_ip = '13.49.133.141'

def select_action(state):
    actions = ['N', 'S', 'E', 'W']
    p = f"[{state[0][0]} {state[0][1]}]"
    print(p)
    paths.append(p) 
    if len(paths) >=2:
        cheak_point()
        
        
        available_values = G_moves[p]
        random_action =random.choice(available_values)
        if len(available_values) == 1:
            elemenate(random_action)
        while(random_action == rev_actions[prev_acc[-1]] and len(available_values)>1):
            random_action =random.choice(available_values)
        save_action(random_action)
        action_index = actions.index(random_action)
        return random_action, action_index

    else:
        available_values = G_moves[p]
        random_action =random.choice(available_values)
        save_action(random_action)
        action_index = actions.index(random_action)
        return random_action, action_index


def move(agent_id, action):
    response = requests.post(f'http://{server_ip}:5000/move', json={"agentId": agent_id, "action": action})
    return response

def solve(agent_id,  riddle_type, solution):
    response = requests.post(f'http://{server_ip}:5000/solve', json={"agentId": agent_id, "riddleType": riddle_type, "solution": solution}) 
    print(response.json()) 
    return response

def get_obv_from_response(response):
    directions = response.json()['directions']
    distances = response.json()['distances']
    position = response.json()['position']
    obv = [position, distances, directions] 
    return obv

        
def submission_inference(riddle_solvers):

    response = requests.post(f'http://{server_ip}:5000/init', json={"agentId": agent_id})
    print(response)
    obv = get_obv_from_response(response)
    t = 0
    while(True):
        t+=1
        # Select an action
        state_0 = obv
        action, action_index = select_action(state_0) # Random action
        response = move(agent_id, action)
        if not response.status_code == 200:
            print(response)
            break

        obv = get_obv_from_response(response)
        print(response.json())

        if not response.json()['riddleType'] == None:
            if  response.json()['riddleType'] not in rids_solved:
                rids_solved.append(response.json()['riddleType'])
                solution = riddle_solvers[response.json()['riddleType']](response.json()['riddleQuestion'])
                response = solve(agent_id, response.json()['riddleType'], solution)


        # THIS IS A SAMPLE TERMINATING CONDITION WHEN THE AGENT REACHES THE EXIT
        # IMPLEMENT YOUR OWN TERMINATING CONDITION
        if (len(rids_solved) >=2):
            response = requests.post(f'http://{server_ip}:5000/leave', json={"agentId": agent_id})
            break


if __name__ == "__main__":
    
    agent_id = "phdy6VvenJ"
    riddle_solvers = {'cipher': cipher_solver, 'captcha': captcha_solver, 'pcap': pcap_solver, 'server': server_solver}
    submission_inference(riddle_solvers)
# Out:
# <Response [200]>
# [0 0]
# {'directions': [[0, 1], [1, 1], [1, 1], [1, 1]], 'distances': [2, 9, 13, 16], 'position': [1, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 0]
# {'directions': [[0, 1], [1, 1], [1, 1], [1, 1]], 'distances': [2, 9, 13, 16], 'position': [1, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 0]
# {'directions': [[0, 1], [1, 1], [1, 1], [1, 1]], 'distances': [2, 9, 13, 16], 'position': [1, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 0]
# {'directions': [[1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [3, 10, 14, 17], 'position': [0, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 0]
# {'directions': [[1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [2, 9, 13, 16], 'position': [0, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 1]
# {'directions': [[1, 0], [1, 1], [1, 1], [1, 1]], 'distances': [1, 8, 12, 15], 'position': [0, 2], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 2]
# {'directions': [[1, 0], [1, 1], [1, 1], [1, 1]], 'distances': [1, 8, 12, 15], 'position': [0, 2], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 2]
# {'directions': [[1, 0], [1, 1], [1, 1], [1, 1]], 'distances': [1, 8, 12, 15], 'position': [0, 2], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 2]
# {'directions': [[1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [2, 9, 13, 16], 'position': [0, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 1]
# {'directions': [[0, 1], [1, 1], [1, 1], [1, 1]], 'distances': [1, 8, 12, 15], 'position': [1, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 1]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [2, 7, 11, 14], 'position': [2, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 1]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [3, 8, 12, 15], 'position': [2, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 0]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [4, 7, 11, 14], 'position': [3, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 0]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [5, 6, 10, 13], 'position': [4, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 0]
# {'directions': [[-1, 1], [1, 1], [0, 1], [1, 1]], 'distances': [6, 5, 9, 12], 'position': [5, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [5 0]
# {'directions': [[-1, 1], [1, 1], [0, 1], [1, 1]], 'distances': [6, 5, 9, 12], 'position': [5, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [5 0]
# {'directions': [[-1, 1], [1, 1], [0, 1], [1, 1]], 'distances': [5, 4, 8, 11], 'position': [5, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [5 1]
# {'directions': [[-1, 1], [1, 1], [0, 1], [1, 1]], 'distances': [5, 4, 8, 11], 'position': [5, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [5 1]
# {'directions': [[-1, 1], [1, 1], [0, 1], [1, 1]], 'distances': [5, 4, 8, 11], 'position': [5, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [5 1]
# {'directions': [[-1, 1], [1, 1], [0, 1], [1, 1]], 'distances': [6, 5, 9, 12], 'position': [5, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [5 0]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [5, 6, 10, 13], 'position': [4, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 0]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [4, 7, 11, 14], 'position': [3, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 0]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [3, 8, 12, 15], 'position': [2, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 0]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [2, 7, 11, 14], 'position': [2, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 1]
# {'directions': [[0, 1], [1, 1], [1, 1], [1, 1]], 'distances': [1, 8, 12, 15], 'position': [1, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 1]
# {'directions': [[0, 1], [1, 1], [1, 1], [1, 1]], 'distances': [1, 8, 12, 15], 'position': [1, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 1]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [2, 7, 11, 14], 'position': [2, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 1]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [2, 7, 11, 14], 'position': [2, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 1]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [3, 6, 10, 13], 'position': [3, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 1]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [3, 6, 10, 13], 'position': [3, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 1]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [3, 6, 10, 13], 'position': [3, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 1]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [2, 7, 11, 14], 'position': [2, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 1]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [3, 8, 12, 15], 'position': [2, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 0]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [4, 7, 11, 14], 'position': [3, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 0]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [5, 6, 10, 13], 'position': [4, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 0]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [4, 5, 9, 12], 'position': [4, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 1]
# {'directions': [[-1, 0], [1, 1], [1, 1], [1, 1]], 'distances': [3, 4, 8, 11], 'position': [4, 2], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 2]
# {'directions': [[-1, -1], [1, 0], [1, 1], [1, 1]], 'distances': [4, 3, 7, 10], 'position': [4, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 3]
# {'directions': [[-1, -1], [1, 0], [1, 1], [1, 1]], 'distances': [3, 4, 8, 11], 'position': [3, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 3]
# {'directions': [[-1, -1], [1, 0], [1, 1], [1, 1]], 'distances': [3, 4, 8, 11], 'position': [3, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 3]
# {'directions': [[-1, -1], [1, 0], [1, 1], [1, 1]], 'distances': [3, 4, 8, 11], 'position': [3, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 3]
# {'directions': [[-1, 0], [1, 1], [1, 1], [1, 1]], 'distances': [2, 5, 9, 12], 'position': [3, 2], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 2]
# {'directions': [[-1, 0], [1, 1], [1, 1], [1, 1]], 'distances': [2, 5, 9, 12], 'position': [3, 2], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 2]
# {'directions': [[-1, -1], [1, 0], [1, 1], [1, 1]], 'distances': [3, 4, 8, 11], 'position': [3, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 3]
# {'directions': [[-1, -1], [1, 0], [1, 1], [1, 1]], 'distances': [4, 3, 7, 10], 'position': [4, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 3]
# {'directions': [[-1, -1], [1, 0], [1, 1], [1, 1]], 'distances': [4, 3, 7, 10], 'position': [4, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 3]
# {'directions': [[-1, 0], [1, 1], [1, 1], [1, 1]], 'distances': [3, 4, 8, 11], 'position': [4, 2], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 2]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [4, 5, 9, 12], 'position': [4, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 1]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [5, 6, 10, 13], 'position': [4, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 0]
# {'directions': [[-1, 1], [1, 1], [0, 1], [1, 1]], 'distances': [6, 5, 9, 12], 'position': [5, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [5 0]
# {'directions': [[-1, 1], [1, 1], [0, 1], [1, 1]], 'distances': [5, 4, 8, 11], 'position': [5, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [5 1]
# {'directions': [[-1, 1], [1, 1], [0, 1], [1, 1]], 'distances': [5, 4, 8, 11], 'position': [5, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [5 1]
# {'directions': [[-1, 1], [1, 1], [0, 1], [1, 1]], 'distances': [6, 5, 9, 12], 'position': [5, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [5 0]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [5, 6, 10, 13], 'position': [4, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 0]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [4, 7, 11, 14], 'position': [3, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 0]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [3, 8, 12, 15], 'position': [2, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 0]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [2, 7, 11, 14], 'position': [2, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 1]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [3, 6, 10, 13], 'position': [3, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 1]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [3, 6, 10, 13], 'position': [3, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 1]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [2, 7, 11, 14], 'position': [2, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 1]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [3, 8, 12, 15], 'position': [2, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 0]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [4, 7, 11, 14], 'position': [3, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 0]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [5, 6, 10, 13], 'position': [4, 0], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 0]
# {'directions': [[-1, 1], [1, 1], [1, 1], [1, 1]], 'distances': [4, 5, 9, 12], 'position': [4, 1], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 1]
# {'directions': [[-1, 0], [1, 1], [1, 1], [1, 1]], 'distances': [3, 4, 8, 11], 'position': [4, 2], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 2]
# {'directions': [[-1, -1], [1, 0], [1, 1], [1, 1]], 'distances': [4, 3, 7, 10], 'position': [4, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 3]
# {'directions': [[-1, -1], [1, 0], [1, 1], [1, 1]], 'distances': [4, 3, 7, 10], 'position': [4, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 3]
# {'directions': [[-1, -1], [1, 0], [1, 1], [1, 1]], 'distances': [3, 4, 8, 11], 'position': [3, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 3]
# {'directions': [[-1, 0], [1, 1], [1, 1], [1, 1]], 'distances': [2, 5, 9, 12], 'position': [3, 2], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 2]
# {'directions': [[-1, 0], [1, 1], [1, 1], [1, 1]], 'distances': [1, 6, 10, 13], 'position': [2, 2], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 2]
# {'directions': [[-1, -1], [1, 0], [1, 1], [1, 1]], 'distances': [2, 5, 9, 12], 'position': [2, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 3]
# {'directions': [[-1, -1], [1, 0], [1, 1], [1, 1]], 'distances': [2, 5, 9, 12], 'position': [2, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 3]
# {'directions': [[-1, -1], [1, 0], [1, 1], [1, 1]], 'distances': [2, 5, 9, 12], 'position': [2, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 3]
# {'directions': [[-1, 0], [1, 1], [1, 1], [1, 1]], 'distances': [1, 6, 10, 13], 'position': [2, 2], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 2]
# {'directions': [[0, 0], [1, 1], [1, 1], [1, 1]], 'distances': [0, 7, 11, 14], 'position': [1, 2], 'rescuedItems': 0, 'riddleQuestion': [[255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255], [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 224, 176, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 197, 74, 100, 142, 220, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255], [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 175, 111, 52, 13, 20, 203, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 111, 0, 13, 15, 110, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255], [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 63, 0, 1, 0, 43, 196, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 41, 0, 1, 0, 6, 199, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 25 ...
# {'directions': [[0, 0], [1, 1], [1, 1], [1, 1]], 'distances': [-1, 7, 11, 14], 'position': [1, 2], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 2]
# {'directions': [[0, 0], [1, 0], [1, 1], [1, 1]], 'distances': [-1, 6, 10, 13], 'position': [1, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 3]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 9, 12], 'position': [1, 4], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 4]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 9, 12], 'position': [1, 4], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 4]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 9, 12], 'position': [1, 4], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 4]
# {'directions': [[0, 0], [1, 0], [1, 1], [1, 1]], 'distances': [-1, 6, 10, 13], 'position': [1, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 3]
# {'directions': [[0, 0], [1, 0], [1, 1], [1, 1]], 'distances': [-1, 7, 11, 14], 'position': [0, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 3]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 10, 13], 'position': [0, 4], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 4]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 9, 9, 12], 'position': [0, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 8, 11], 'position': [1, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 7, 10], 'position': [2, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 6, 9], 'position': [2, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 6, 9], 'position': [2, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 6, 9], 'position': [2, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 7, 10], 'position': [2, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 7, 10], 'position': [2, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 6, 9], 'position': [2, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 9, 7, 10], 'position': [1, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 10, 6, 9], 'position': [1, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 9, 5, 8], 'position': [2, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 4, 7], 'position': [3, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 5, 8], 'position': [3, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 5, 8], 'position': [3, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 6, 6, 9], 'position': [3, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 5, 7, 10], 'position': [3, 4], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 4]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 5, 7, 10], 'position': [3, 4], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 4]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 6, 6, 9], 'position': [3, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 5, 8], 'position': [3, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 4, 7], 'position': [3, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 4, 7], 'position': [3, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 5, 8], 'position': [3, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 6, 6, 9], 'position': [3, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 6, 6, 9], 'position': [3, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 5, 8], 'position': [3, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 4, 7], 'position': [3, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 4, 7], 'position': [3, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 9, 5, 8], 'position': [2, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 9, 5, 8], 'position': [2, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 4, 7], 'position': [3, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 5, 8], 'position': [3, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 6, 6, 9], 'position': [3, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 5, 7, 10], 'position': [3, 4], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 4]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 6, 8, 11], 'position': [2, 4], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 4]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 6, 8, 11], 'position': [2, 4], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 4]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 6, 8, 11], 'position': [2, 4], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 4]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 5, 7, 10], 'position': [3, 4], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 4]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 6, 6, 9], 'position': [3, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 5, 8], 'position': [3, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 4, 7], 'position': [3, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 9, 5, 8], 'position': [2, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 10, 6, 9], 'position': [1, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 11, 7, 10], 'position': [0, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 0]], 'distances': [-1, 12, 6, 9], 'position': [0, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 8]
# {'directions': [[0, 0], [1, -1], [1, 0], [1, -1]], 'distances': [-1, 13, 5, 10], 'position': [0, 9], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 9]
# {'directions': [[0, 0], [1, -1], [1, 0], [1, -1]], 'distances': [-1, 12, 4, 9], 'position': [1, 9], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 9]
# {'directions': [[0, 0], [1, -1], [1, 0], [1, -1]], 'distances': [-1, 11, 3, 8], 'position': [2, 9], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 9]
# {'directions': [[0, 0], [1, -1], [1, 0], [1, -1]], 'distances': [-1, 10, 2, 7], 'position': [3, 9], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 9]
# {'directions': [[0, 0], [1, -1], [1, 0], [1, -1]], 'distances': [-1, 10, 2, 7], 'position': [3, 9], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 9]
# {'directions': [[0, 0], [1, -1], [1, 0], [1, -1]], 'distances': [-1, 10, 2, 7], 'position': [3, 9], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 9]
# {'directions': [[0, 0], [1, -1], [1, 0], [1, -1]], 'distances': [-1, 11, 3, 8], 'position': [2, 9], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 9]
# {'directions': [[0, 0], [1, -1], [1, 0], [1, -1]], 'distances': [-1, 12, 4, 9], 'position': [1, 9], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 9]
# {'directions': [[0, 0], [1, -1], [1, 0], [1, -1]], 'distances': [-1, 13, 5, 10], 'position': [0, 9], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 9]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 0]], 'distances': [-1, 12, 6, 9], 'position': [0, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 8]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 0]], 'distances': [-1, 12, 6, 9], 'position': [0, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 8]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 11, 7, 10], 'position': [0, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 11, 7, 10], 'position': [0, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 10, 6, 9], 'position': [1, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 9, 7, 10], 'position': [1, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 10, 8, 11], 'position': [0, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 10, 8, 11], 'position': [0, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 9, 7, 10], 'position': [1, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 6, 9], 'position': [2, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 7, 10], 'position': [2, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 8, 11], 'position': [1, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 8, 11], 'position': [1, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 7, 10], 'position': [2, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 6, 9], 'position': [2, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 9, 7, 10], 'position': [1, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 10, 6, 9], 'position': [1, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 0]], 'distances': [-1, 11, 5, 8], 'position': [1, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 8]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 0]], 'distances': [-1, 11, 5, 8], 'position': [1, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 8]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 0]], 'distances': [-1, 10, 4, 7], 'position': [2, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 8]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 0]], 'distances': [-1, 10, 4, 7], 'position': [2, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 8]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 0]], 'distances': [-1, 11, 5, 8], 'position': [1, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 8]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 10, 6, 9], 'position': [1, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 11, 7, 10], 'position': [0, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 0]], 'distances': [-1, 12, 6, 9], 'position': [0, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 8]
# {'directions': [[0, 0], [1, -1], [1, 0], [1, -1]], 'distances': [-1, 13, 5, 10], 'position': [0, 9], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 9]
# {'directions': [[0, 0], [1, -1], [1, 0], [1, -1]], 'distances': [-1, 12, 4, 9], 'position': [1, 9], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 9]
# {'directions': [[0, 0], [1, -1], [1, 0], [1, -1]], 'distances': [-1, 11, 3, 8], 'position': [2, 9], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 9]
# {'directions': [[0, 0], [1, -1], [1, 0], [1, -1]], 'distances': [-1, 12, 4, 9], 'position': [1, 9], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 9]
# {'directions': [[0, 0], [1, -1], [1, 0], [1, -1]], 'distances': [-1, 13, 5, 10], 'position': [0, 9], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 9]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 0]], 'distances': [-1, 12, 6, 9], 'position': [0, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 8]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 11, 7, 10], 'position': [0, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 10, 6, 9], 'position': [1, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 9, 7, 10], 'position': [1, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 6, 9], 'position': [2, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 7, 10], 'position': [2, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 8, 11], 'position': [1, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 9, 9, 12], 'position': [0, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 10, 13], 'position': [0, 4], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 4]
# {'directions': [[0, 0], [1, 0], [1, 1], [1, 1]], 'distances': [-1, 7, 11, 14], 'position': [0, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 3]
# {'directions': [[0, 0], [1, 0], [1, 1], [1, 1]], 'distances': [-1, 6, 10, 13], 'position': [1, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 3]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 9, 12], 'position': [1, 4], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 4]
# {'directions': [[0, 0], [1, 0], [1, 1], [1, 1]], 'distances': [-1, 6, 10, 13], 'position': [1, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 3]
# {'directions': [[0, 0], [1, 0], [1, 1], [1, 1]], 'distances': [-1, 7, 11, 14], 'position': [0, 3], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 3]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 10, 13], 'position': [0, 4], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 4]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 9, 9, 12], 'position': [0, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [0 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 8, 11], 'position': [1, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 7, 7, 10], 'position': [2, 5], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 5]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 8, 6, 9], 'position': [2, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 9, 7, 10], 'position': [1, 6], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 6]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 1]], 'distances': [-1, 10, 6, 9], 'position': [1, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 7]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 0]], 'distances': [-1, 11, 5, 8], 'position': [1, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [1 8]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 0]], 'distances': [-1, 10, 4, 7], 'position': [2, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [2 8]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 0]], 'distances': [-1, 9, 3, 6], 'position': [3, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [3 8]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 0]], 'distances': [-1, 8, 2, 5], 'position': [4, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 8]
# {'directions': [[0, 0], [1, -1], [0, 1], [1, 0]], 'distances': [-1, 7, 1, 4], 'position': [5, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [5 8]
# {'directions': [[0, 0], [1, -1], [0, 1], [1, 1]], 'distances': [-1, 6, 2, 5], 'position': [5, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [5 7]
# {'directions': [[0, 0], [1, -1], [-1, 1], [1, 1]], 'distances': [-1, 5, 3, 4], 'position': [6, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [6 7]
# {'directions': [[0, 0], [0, -1], [-1, 1], [1, 1]], 'distances': [-1, 4, 4, 3], 'position': [7, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [7 7]
# {'directions': [[0, 0], [0, -1], [-1, 1], [1, 1]], 'distances': [-1, 4, 4, 3], 'position': [7, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [7 7]
# {'directions': [[0, 0], [0, -1], [-1, 1], [1, 1]], 'distances': [-1, 4, 4, 3], 'position': [7, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [7 7]
# {'directions': [[0, 0], [1, -1], [-1, 1], [1, 1]], 'distances': [-1, 5, 3, 4], 'position': [6, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [6 7]
# {'directions': [[0, 0], [1, -1], [0, 1], [1, 1]], 'distances': [-1, 6, 2, 5], 'position': [5, 7], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [5 7]
# {'directions': [[0, 0], [1, -1], [0, 1], [1, 0]], 'distances': [-1, 7, 1, 4], 'position': [5, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [5 8]
# {'directions': [[0, 0], [1, -1], [1, 1], [1, 0]], 'distances': [-1, 8, 2, 5], 'position': [4, 8], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 8]
# {'directions': [[0, 0], [1, -1], [1, 0], [1, -1]], 'distances': [-1, 9, 1, 6], 'position': [4, 9], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
# [4 9]
# {'directions': [[0, 0], [1, -1], [0, 0], [1, -1]], 'distances': [-1, 8, 0, 5], 'position': [5, 9], 'rescuedItems': 0, 'riddleQuestion': '...', 'riddleType': 'pcap'}
# {'directions': [[0, 0], [1, -1], [0, 0], [1, -1]], 'distances': [-1, 8, -1, 5], 'position': [5, 9], 'rescuedItems': 0, 'riddleQuestion': None, 'riddleType': None}
